# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
tqdm.pandas()

# %%
df = pd.read_csv("../data/processed/b01_kherson.csv")

# %%
df.head()
# Out:
#                     id            author_id           author  \
# 0  1494225904255516677  1228738866577801227         seospage
# 1  1494317225611776003  1196471635974508544     BillBrooker4
# 2  1494605370178027522   917536742755860480   CintelAlliance
# 3  1494671821412909056           3397244179  elenaevdokimov7
# 4  1494695325768032258             24842995        Orgetorix
#
#                                            tweet_url  has_media        date  \
# 0  https://twitter.com/1228738866577801227/status...       True  2022-02-17
# 1  https://twitter.com/1196471635974508544/status...      False  2022-02-17
# 2  https://twitter.com/917536742755860480/status/...      False  2022-02-18
# 3  https://twitter.com/3397244179/status/14946718...      False  2022-02-18
# 4  https://twitter.com/24842995/status/1494695325...      False  2022-02-18
#
#                                                 text
# 0  In the European commodity market ICE Futures, ...
# 1  @DennisMisigoy @CaroCastilloCC The population ...
# 2  @DefenceHQ It looks like Ministry of Defence h...
# 3  In Ukraine controlled Kherson, kindergarten st...
# 4    Kherson https://t.co/4hPgXD8Nkc via @britannica

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(
    pd.to_datetime(df["date"]),
    fill=True
)
plt.show()

# %%
og_len = len(df)

# %%
sampled = pd.DataFrame()
for date in tqdm(sorted(df.date.unique())):
    sampled = pd.concat([sampled, df[df.date == date].sample(frac=.10, random_state=42)])
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 327.86it/s]

# %%
sampled
# Out:
#                         id            author_id          author  \
# 2      1494605370178027522   917536742755860480  CintelAlliance
# 17     1495118264694890505  1423617599926063107          ybmuck
# 27     1495462610879328256   717798694817370113       avsec_pro
# 35     1495490090830901253            856959757      walterlekh
# 43     1495567045550698498             80963391       fj_newman
# ...                    ...                  ...             ...
# 28191  1501246352411566082  1499717978815873025       NexthLive
# 28328  1501304840449839109  1104803680719638528   OchanjiSamuel
# 27922  1501139283976994817  1145001497215717376   Shadi_Alkasim
# 27974  1501154062745669632             24765600     smitschagen
# 27804  1501077930390134784           3313946418   priscilagural
#
#                                                tweet_url  has_media  \
# 2      https://twitter.com/917536742755860480/status/...      False
# 17     https://twitter.com/1423617599926063107/status...       True
# 27     https://twitter.com/717798694817370113/status/...      False
# 35     https://twitter.com/856959757/status/149549009...      False
# 43     https://twitter.com/80963391/status/1495567045...      False
# ...                                                  ...        ...
# 28191  https://twitter.com/1499717978815873025/status...      False
# 28328  https://twitter.com/1104803680719638528/status...      False
# 27922  https://twitter.com/1145001497215717376/status...       True
# 27974  https://twitter.com/24765600/status/1501154062...       True
# 27804  https://twitter.com/3313946418/status/15010779...      False
#
#              date                                               text
# 2      2022-02-18  @DefenceHQ It looks like Ministry of Defence h...
# 17     2022-02-19  We have information that Russia is concentrati...
# 27     2022-02-20  Report: Russian military invasion of Ukraine w...
# 35     2022-02-20  Also Russian amphibious fleet positioned in Bl...
# 43     2022-02-21  US intel shows Russian invasion of Ukraine wou...
# ...           ...                                                ...
# 28191  2022-03-08  #Ukraine War - #drones  Shows Intense Close Co...
# 28328  2022-03-08  @ASBMilitary Did Russia lose over 30 helicopte...
# 27922  2022-03-08  The #Russian Aggression on #Ukraine It is repo...
# 27974  2022-03-08  Residents of Oleshky in Kherson region went on...
# 27804  2022-03-08  Russia-Ukraine War: Kharkiv holds out; Russian...
#
# [2840 rows x 7 columns]
